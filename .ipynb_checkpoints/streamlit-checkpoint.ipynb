# %%
import streamlit as st

# %%
st.title("hello")
# Out:
# 2024-11-08 12:22:23.525 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 12:22:24.143
# ...
#   command:
#
#     streamlit run C:\Users\rachi\ml\env\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-08 12:22:24.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
streamlit run Untitled.ipynb
# Out:
#   Cell In[4], line 1
#     streamlit run Untitled.ipynb
#               ^
# SyntaxError: invalid syntax
